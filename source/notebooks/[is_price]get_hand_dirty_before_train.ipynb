# %% [markdown]
# # Comments

# %% [markdown]
# - Ratio pos:neg = 1:36.8
# - Currently, data only covers TV and milk

# %% [markdown]
# # Code

# %%
import sys
sys.path.append('/source/main')

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('/source/main/data_for_train/output/is_price/train.csv')

# %%
df.shape
# Out:
# (461036, 5)

# %%
df['label'].value_counts()
# Out:
# 0    448834
# 1    12202
# Name: label, dtype: int64

# %%
448834/12202
# Out:
# 36.78364202589739

# %%
df[df['label']==1].sample(30)
# Out:
#                                                  id  \
# 165966  9ce25c1e-0004-5387-b9d2-e86c59c9a6d0__6732
# 184401  5819dcad-ac1d-5d5b-b0a7-039a4ea69ea3__4489
# 229968  341036c9-b73e-5da1-89fc-64cbe3806b8e__6732
# 174051  3c3ce67c-fd3a-5222-8917-220363bbf0ec__4489
# 173762  43a3eb7a-bb9d-585a-8cac-2673d62258c7__4637
# 42083   8f8e41e3-cede-5227-a8bd-bf4006c324f8__23709
# 206687  d2a146d5-7aa6-5447-9465-0c3263a1f046__4489
# 183763  efe85fe3-bfd4-53ee-91a5-6b3dcd8e60b9__4489
# 101494  8b1a2af9-1ba1-53fe-8a67-074746c18cca__3245
# 119878  048788d1-38f0-5eea-9b7a-36773a382792__6732
# 145706  821459fc-c9c1-5341-acfb-c8c1350cf873__21357
# 367306  1ac12229-0e42-5a1a-b26b-527f0ca606ad__5200
# 211165  d18b2c7b-617b-58cf-adb9-0695003179db__5200
# 253622  b34c5d36-c3de-55fe-b40d-ddc88aafe415__4489
# 241687  bd796fd9-6df8-559d-ac5b-6d6029d9eec2__4489
# 192494  dc857dd4-eafd-5bbf-8db9-54865c22dd93__5200
# 437844  b9bdc7d2-744f-5889-b915-b661a90d1cb6__23709
# ...
